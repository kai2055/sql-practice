# %%
# %load_ext sql

# %%
# %sql sqlite:///learning.db

# %%
# %%sql
#
# CREATE TABLE students (
#     id INTEGER PRIMARY KEY,
#     name TEXT NOT NULL,
#     age INTEGER,
#     major TEXT
# );
# Out:
#  * sqlite:///learning.db
# Done.
# []
